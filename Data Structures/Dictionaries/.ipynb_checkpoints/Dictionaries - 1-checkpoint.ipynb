# %%
dict1 = dict()
print(dict1)
print(type(dict1))
# Out:
# {}
# <class 'dict'>

# %%
dict2 = {}
print(dict2)
print(type(dict2))
# Out:
# {}
# <class 'dict'>

# %%
student = {"name":"Aryan", "age":21, "grade":98}
print(student)
print(type(student))
# Out:
# {'name': 'Aryan', 'age': 21, 'grade': 98}
# <class 'dict'>

# %%
student = {"name":"Aryan", "age":21, "grade":"A"}
student['grade']
# Out:
# 'A'

# %%
student["age"]
# Out:
# 21

# %%
print(student.get("grade"))
print(student.get("name"))
print(student.get("last_name"))
# Out:
# A
# Aryan
# None

# %%
print(student.get("last_name","Not available"))
# Out:
# Not available

# %%
student['age'] = 33
student['address'] = "India"

# %%
print(student)
# Out:
# {'name': 'Aryan', 'age': 33, 'grade': 'A', 'address': 'India'}

# %%
del student['grade']

# %%
print(student)
# Out:
# {'name': 'Aryan', 'age': 33, 'address': 'India'}

# %%
keys = student.keys()
values = student.values()
print(keys)
print(values)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Aryan', 33, 'India'])

# %%
items = student.items()
print(items)
# Out:
# dict_items([('name', 'Aryan'), ('age', 33), ('address', 'India')])

# %%
student_copy = student
print(student)
print(student_copy)
# Out:
# {'name': 'Aryan', 'age': 33, 'address': 'India'}
# {'name': 'Aryan', 'age': 33, 'address': 'India'}

# %%
student["name"] = "krish"
print(student)
print(student_copy)
# Out:
# {'name': 'krish', 'age': 33, 'address': 'India'}
# {'name': 'krish', 'age': 33, 'address': 'India'}

# %%
student_copy1 = student.copy()
print(student_copy1)
print(student)
# Out:
# {'name': 'krish', 'age': 33, 'address': 'India'}
# {'name': 'krish', 'age': 33, 'address': 'India'}

# %%
student["name"] = "krish2"
print(student)
print(student_copy1)
# Out:
# {'name': 'krish2', 'age': 33, 'address': 'India'}
# {'name': 'krish', 'age': 33, 'address': 'India'}

# %%
for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address

# %%
for values in student.values():
    print(values)
# Out:
# krish2
# 33
# India

# %%
for key, value in student.items():
    print(f"{key} : {value}")
# Out:
# name : krish2
# age : 33
# address : India

# %%
students = {
    "student1":{"name":"Aryan", "Age":21},
    "student2":{"name":"Rahul", "Age":22}
}

# %%
print(students)
# Out:
# {'student1': {'name': 'Aryan', 'Age': 21}, 'student2': {'name': 'Rahul', 'Age': 22}}

# %%
students["student1"]["Age"]
# Out:
# 21

# %%
students["student2"]["name"]
# Out:
# 'Rahul'

# %%
for student_id, student_info in students.items():
    print(f"{student_id} : {student_info}")
    for key, value in student_info.items():
        print(f"{key} : {value}")
# Out:
# student1 : {'name': 'Aryan', 'Age': 21}
# name : Aryan
# Age : 21
# student2 : {'name': 'Rahul', 'Age': 22}
# name : Rahul
# Age : 22

# %%
squares = {x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
evens = {x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
numbers = [1,2,2,3,3,3,4,4,4,4]
frequency = {}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1

print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
dict1 = {"a":1, "b":2}
dict2 = {"b":3, "c":4}
merged_dict = {**dict1, **dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
