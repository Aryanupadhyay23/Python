# %% [markdown]
# ## Python Output

# %%
print("hello world")
# Out:
# hello world

# %%
print("learning python")
# Out:
# learning python

# %%
print(5 + 4)
# Out:
# 9

# %%
print(True)
# Out:
# True

# %%
print("hello", 5+7, "world")
# Out:
# hello 12 world

# %%
print("hello", 5+7, "world", sep="\n")
# Out:
# hello
# 12
# world

# %%
print("hello", 5+7, "world", sep="/")
# Out:
# hello/12/world

# %%
print("hello", 5+7, "world", sep=" $ ")
# Out:
# hello $ 12 $ world

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello", end=" ")
print("World", end=" ")
# Out:
# Hello World

# %%
print("Hello", end=" - ")
print("World")
# Out:
# Hello - World

# %% [markdown]
# ## Data Types

# %%
print(8, type(8))
# Out:
# 8 <class 'int'>

# %%
print(8.5, type(8.5))
# Out:
# 8.5 <class 'float'>

# %%
print(True, type(True))
# Out:
# True <class 'bool'>

# %%
print('string', type('string'))
# Out:
# string <class 'str'>

# %%
print(5+6j, type(5+6j))
# Out:
# (5+6j) <class 'complex'>

# %%
print([1,2,3], type([1,2,3]))
# Out:
# [1, 2, 3] <class 'list'>

# %%
print((1,2,3), type((1,2,3)))
# Out:
# (1, 2, 3) <class 'tuple'>

# %%
print({1,2,3}, type({1,2,3}))
# Out:
# {1, 2, 3} <class 'set'>

# %%
print({"one":1,"two":2,"three":3}, type({"one":1,"two":2,"three":3}))
# Out:
# {'one': 1, 'two': 2, 'three': 3} <class 'dict'>

# %% [markdown]
# ## variables

# %%
name = "Aryan"
print(name)
# Out:
# Aryan

# %%
value = 5
print(value)
# Out:
# 5

# %%
a = 5
b = 6
print(a+b)
# Out:
# 11

# %%
a = 5
print(a)
a = "Aryan"
print(a)
# Out:
# 5
# Aryan

# %%
a, b, c = 1, 2, 3
print(a, b, c)
# Out:
# 1 2 3

# %%
a = b = c = 5
print(a, b, c)
# Out:
# 5 5 5

# %% [markdown]
# ## comments

# %%
# add a and b
a = 5 
b = 6
print(a + b)
# Out:
# 11

# %%
'''
This looks like a multi-line comment,
but it is actually a multi-line string.
Python just ignores it if not assigned.
'''
# Out:
# '\nThis looks like a multi-line comment,\nbut it is actually a multi-line string.\nPython just ignores it if not assigned.\n'

# %%
"""
Another multi-line string
used like a comment.
"""
# Out:
# '\nAnother multi-line string\nused like a comment.\n'

# %% [markdown]
# ## Type Conversion

# %%
print(5+0.5)
# Out:
# 5.5

# %%
print(int(5.5)+6)
# Out:
# 11

# %%
print(int(5.6)+6)
# Out:
# 11

# %%
print(int("5")+4)
# Out:
# 9
