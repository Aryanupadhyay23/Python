# %%
import array

# %%
arr = array.array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
# Out:
# 10

# %%
print(random.choice(['apple','banana','cherry']))
# Out:
# cherry

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dell\\OneDrive\\Documents\\Desktop\\PYTHON\\modules and packages'

# %%
os.mkdir('test_dir')

# %%
import shutil

# %%
shutil.copyfile('source.txt','destination.txt')

# %%
import json
data = {'name':'Aryan',"age":21}
json_str = json.dumps(data)
print(json_str)
print(type(json_str))
# Out:
# {"name": "Aryan", "age": 21}
# <class 'str'>

# %%
parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {'name': 'Aryan', 'age': 21}
# <class 'dict'>
